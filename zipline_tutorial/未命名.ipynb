# %%
import sys
print(sys.version)
# Out:
# 3.4.5 |Continuum Analytics, Inc.| (default, Jul  2 2016, 17:47:47)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %%
import zipline

# %%
# %load_ext zipline

# %%
from zipline.api import order, record, symbol

def initialize(context):
    pass

def handle_data(context,data):
    order('AAPL',10)
    record(AAPL=data.current(symbol('AAPL'),'price'))

# %%
# %zipline --bundle quantopian-quandl --start 2016-1-1 --end 2017-12-31
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/calendars/calendar_utils.py in get_calendar(self, name)
#      81         try:
# ---> 82             factory = self._calendar_factories[canonical_name]
#      83         except KeyError:
#
# KeyError: 'XNYS'
#
# During handling of the above exception, another exception occurred:
#
# InvalidCalendarName                       Traceback (most recent call last)
# <ipython-input-9-85363cde4b62> in <module>()
# ----> 1 get_ipython().magic('zipline --bundle quantopian-quandl --start 2016-1-1 --end 2017-12-31')
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/__main__.py in zipline_magic(line, cell)
#     273             '%s%%zipline' % ((cell or '') and '%'),
#     274             # don't use system exit and propogate errors to the caller
# --> 275             standalone_mode=False,
#     276         )
#     277     except SystemExit as e:
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in main(self, args, prog_name, complete_var, standalone_mode, **extra)
#     695             try:
#     696                 with self.make_context(prog_name, args, **extra) as ctx:
# --> 697                     rv = self.invoke(ctx)
#     698                     if not standalone_mode:
#     699                         return rv
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in invoke(self, ctx)
#     893         """
#     894         if self.callback is not None:
# --> 895             return ctx.invoke(self.callback, **ctx.params)
#     896
#     897
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in invoke(*args, **kwargs)
#     533         with augment_usage_errors(self):
#     534             with ctx:
# --> 535                 return callback(*args, **kwargs)
#     536
#     537     def forward(*args, **kwargs):
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/decorators.py in new_func(*args, **kwargs)
#      15     """
#      16     def new_func(*args, **kwargs):
# ---> 17         return f(get_current_context(), *args, **kwargs)
#      18     return update_wrapper(new_func, f)
#      19
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/__main__.py in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, print_algo, local_namespace)
#     238         print_algo=print_algo,
#     239         local_namespace=local_namespace,
# --> 240         environ=os.environ,
#     241     )
#     242
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/run_algo.py in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, data, bundle, bundle_timestamp, start, end, output, print_algo, local_namespace, environ)
#     117             bundle,
#     118             environ,
# --> 119             bundle_timestamp,
#     120         )
#     121
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/bundles/core.py in load(name, environ, timestamp)
#     525             ),
#     526             equity_minute_bar_reader=BcolzMinuteBarReader(
# --> 527                 minute_equity_path(name, timestr, environ=environ),
#     528             ),
#     529             equity_daily_bar_reader=BcolzDailyBarReader(
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in __init__(self, rootdir, sid_cache_size)
#     903         self._rootdir = rootdir
#     904
# --> 905         metadata = self._get_metadata()
#     906
#     907         self._start_session = metadata.start_session
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in _get_metadata(self)
#     948
#     949     def _get_metadata(self):
# --> 950         return BcolzMinuteBarMetadata.read(self._rootdir)
#     951
#     952     @property
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in read(cls, rootdir)
#     227
#     228             if version >= 2:
# --> 229                 calendar = get_calendar(raw_data['calendar_name'])
#     230                 start_session = pd.Timestamp(
#     231                     raw_data['start_session'], tz='UTC')
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/calendars/calendar_utils.py in get_calendar(self, name)
#      83         except KeyError:
#      84             # We don't have a factory registered for this name.  Barf.
# ---> 85             raise InvalidCalendarName(calendar_name=name)
#      86
#      87         # Cache the calendar for future use.
#
# InvalidCalendarName: The requested TradingCalendar, XNYS, does not exist.

# %%
# %zipline --bundle quantopian-quandl --start 2000-1-1 --end 2012-1-1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/calendars/calendar_utils.py in get_calendar(self, name)
#      81         try:
# ---> 82             factory = self._calendar_factories[canonical_name]
#      83         except KeyError:
#
# KeyError: 'XNYS'
#
# During handling of the above exception, another exception occurred:
#
# InvalidCalendarName                       Traceback (most recent call last)
# <ipython-input-12-c4d57080afec> in <module>()
# ----> 1 get_ipython().magic('zipline --bundle quantopian-quandl --start 2000-1-1 --end 2012-1-1')
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/__main__.py in zipline_magic(line, cell)
#     273             '%s%%zipline' % ((cell or '') and '%'),
#     274             # don't use system exit and propogate errors to the caller
# --> 275             standalone_mode=False,
#     276         )
#     277     except SystemExit as e:
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in main(self, args, prog_name, complete_var, standalone_mode, **extra)
#     695             try:
#     696                 with self.make_context(prog_name, args, **extra) as ctx:
# --> 697                     rv = self.invoke(ctx)
#     698                     if not standalone_mode:
#     699                         return rv
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in invoke(self, ctx)
#     893         """
#     894         if self.callback is not None:
# --> 895             return ctx.invoke(self.callback, **ctx.params)
#     896
#     897
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/core.py in invoke(*args, **kwargs)
#     533         with augment_usage_errors(self):
#     534             with ctx:
# --> 535                 return callback(*args, **kwargs)
#     536
#     537     def forward(*args, **kwargs):
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/click/decorators.py in new_func(*args, **kwargs)
#      15     """
#      16     def new_func(*args, **kwargs):
# ---> 17         return f(get_current_context(), *args, **kwargs)
#      18     return update_wrapper(new_func, f)
#      19
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/__main__.py in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, print_algo, local_namespace)
#     238         print_algo=print_algo,
#     239         local_namespace=local_namespace,
# --> 240         environ=os.environ,
#     241     )
#     242
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/run_algo.py in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, data, bundle, bundle_timestamp, start, end, output, print_algo, local_namespace, environ)
#     117             bundle,
#     118             environ,
# --> 119             bundle_timestamp,
#     120         )
#     121
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/bundles/core.py in load(name, environ, timestamp)
#     525             ),
#     526             equity_minute_bar_reader=BcolzMinuteBarReader(
# --> 527                 minute_equity_path(name, timestr, environ=environ),
#     528             ),
#     529             equity_daily_bar_reader=BcolzDailyBarReader(
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in __init__(self, rootdir, sid_cache_size)
#     903         self._rootdir = rootdir
#     904
# --> 905         metadata = self._get_metadata()
#     906
#     907         self._start_session = metadata.start_session
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in _get_metadata(self)
#     948
#     949     def _get_metadata(self):
# --> 950         return BcolzMinuteBarMetadata.read(self._rootdir)
#     951
#     952     @property
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/data/minute_bars.py in read(cls, rootdir)
#     227
#     228             if version >= 2:
# --> 229                 calendar = get_calendar(raw_data['calendar_name'])
#     230                 start_session = pd.Timestamp(
#     231                     raw_data['start_session'], tz='UTC')
#
# /home/qin/anaconda3/envs/demo/lib/python3.4/site-packages/zipline/utils/calendars/calendar_utils.py in get_calendar(self, name)
#      83         except KeyError:
#      84             # We don't have a factory registered for this name.  Barf.
# ---> 85             raise InvalidCalendarName(calendar_name=name)
#      86
#      87         # Cache the calendar for future use.
#
# InvalidCalendarName: The requested TradingCalendar, XNYS, does not exist.
